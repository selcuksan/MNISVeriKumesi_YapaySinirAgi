# %% [markdown]
# ## MNİST VERİ KÜMESİNİ YÜKLEMEK

# %%
from keras.datasets import mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ## Yapay sinir ağı mimarisi

# %%
from keras import models
from keras import layers

# %%
network  = models.Sequential()

# %%
network.add(layers.Dense(512, activation="relu", input_shape = (28*28,)))

# %%
network.add(layers.Dense(10,activation="softmax"))

# %% [markdown]
# ## YSA modelinin derlenmesi

# %%
network.compile(optimizer="rmsprop",
                loss = "categorical_crossentropy",
                metrics = ["accuracy"])

# %% [markdown]
# ## Girişlerin ve etiketlerin ölçeklendirilmesi

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
from keras.utils import to_categorical
train_labels  = to_categorical(train_labels)
test_labels  = to_categorical(test_labels)

# %% [markdown]
# ## YSA MODELİNİN EĞİTİLMESİ

# %%
network.fit(train_images,train_labels,epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2569 - accuracy: 0.9250
# Epoch 2/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1037 - accuracy: 0.9692
# Epoch 3/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0686 - accuracy: 0.9801
# Epoch 4/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0499 - accuracy: 0.9849
# Epoch 5/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0382 - accuracy: 0.9884

# %%
test_loss, test_accuracy = network.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0712 - accuracy: 0.9791

# %%
test_loss
# Out:
# 0.07116387784481049

# %%
test_accuracy
# Out:
# 0.9790999889373779
